# %% [markdown]
# # Assgn011 — Optimizers and Learning-Rate Schedules
#
# Thin wrapper around `src.pipeline.optimizers_lab.run_all`. Run from the `Assign_0011` root so imports resolve.
#
# ```text
# python tests/assgn011_optimizers_lab.py
# python -m pytest tests/test_assgn011.py -q
# ```

# %%
# Colab setup — upload Assign_0011_colab.zip to /content first, then uncomment:
# !unzip -q -o /content/Assign_0011_colab.zip -d /content/Assign_0011
# %cd /content/Assign_0011
# !pip -q install -r requirements.txt
# !ls
# Expected: src/  tests/  notebooks/  requirements.txt
# Open notebook: /content/Assign_0011/notebooks/assgn011_optimizers.ipynb
# Lab writes: /content/Assign_0011/reports/  (13 files when PASS)
#
# Forbidden: relative paths like content/Assign_0011 (creates /content/content/...)

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if not (ROOT / "src").is_dir():
    # notebook may live under notebooks/
    ROOT = Path.cwd().parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.pipeline.optimizers_lab import run_all

results = run_all(ROOT / "reports")
print("all_ok:", results["all_ok"])
print("summary:", results["summary_path"])
for k in ("task1_adam_hand", "task2_bias", "task3_ratio", "task4_schedules", "task5_lr_sweep"):
    print(k, "->", results[k].get("ok"))
